# %%
import os

print(os.getcwd())
# Out:
# d:\ECG-Cardiac-Risk-Prediction\notebooks

# %%
import os

print(os.path.exists('../datasets/mit-bih/100.dat'))
print(os.path.exists('../datasets/mit-bih/100.hea'))
print(os.path.exists('../datasets/mit-bih/100.atr'))
# Out:
# True
# True
# True

# %%
import wfdb

record = wfdb.rdrecord('../datasets/mit-bih/100')

print("ECG Loaded Successfully")
print(record)
# Out:
# ECG Loaded Successfully
# ...

# %%
import matplotlib.pyplot as plt

signal = record.p_signal[:,0]

plt.figure(figsize=(15,4))
plt.plot(signal[:2000])

plt.title("ECG Signal")
plt.xlabel("Time")
plt.ylabel("Amplitude")

plt.show()

# %%
import matplotlib.pyplot as plt

signal = record.p_signal[:,0]

plt.figure(figsize=(15,4))
plt.plot(signal[:2000])

plt.title("ECG Signal")
plt.xlabel("Time")
plt.ylabel("Amplitude")

plt.show()
